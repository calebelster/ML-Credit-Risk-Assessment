# %%
import pandas as pd

df = pd.read_csv('data/credit_risk_dataset.csv')

# %%
filtered_df = df[df['loan_status'] == 1]
top10_rows = filtered_df.nlargest(10, 'person_income')

top10_rows
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 25714          32         703800                  RENT               14.0
# 17840          35         648000              MORTGAGE                6.0
# 27881          28         604000              MORTGAGE               12.0
# 28770          28         604000              MORTGAGE               12.0
# 29127          44         584800              MORTGAGE                4.0
# 29129          40         540600              MORTGAGE                8.0
# 31914          42         499800                   OWN                4.0
# 17849          33         468000              MORTGAGE               14.0
# 29132          39         403750              MORTGAGE               10.0
# 27876          34         397800              MORTGAGE                5.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 25714            MEDICAL          D      12000          15.33            1
# ...
